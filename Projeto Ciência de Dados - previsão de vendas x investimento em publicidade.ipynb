# %% [markdown]
# # Projeto Ciência de Dados - Previsão de Vendas
#
# - Nosso desafio é conseguir prever as vendas que vamos ter em determinado período com base nos gastos em anúncios nas 3 grandes redes que a empresa Hashtag investe: TV, Jornal e Rádio
#
# - Base de Dados: https://drive.google.com/drive/folders/1o2lpxoi9heyQV1hIlsHXWSfDkBPtze-V?usp=sharing

# %% [markdown]
# ### Passo a Passo de um Projeto de Ciência de Dados
#
# - Passo 1: Entendimento do Desafio
# - Passo 2: Entendimento da Área/Empresa
# - Passo 3: Extração/Obtenção de Dados
# - Passo 4: Ajuste de Dados (Tratamento/Limpeza)
# - Passo 5: Análise Exploratória
# - Passo 6: Modelagem + Algoritmos (Aqui que entra a Inteligência Artificial, se necessário)
# - Passo 7: Interpretação de Resultados

# %% [markdown]
# # Projeto Ciência de Dados - Previsão de Vendas
#
# - Prever as vendas que vamos ter em determinado período com base nos gastos em anúncios nas 3 grandes redes que a empresa investe: TV, Jornal e Rádio
# - TV, Jornal e Rádio estão em milhares de reais
# - Vendas estão em milhões

# %% [markdown]
# #### Importar a Base de dados

# %%
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit-learn

# %%
import pandas as pd

tabela = pd.read_csv("advertising.csv")
display(tabela)
# Out:
#         TV  Radio  Jornal  Vendas
# 0    230.1   37.8    69.2    22.1
# 1     44.5   39.3    45.1    10.4
# 2     17.2   45.9    69.3    12.0
# 3    151.5   41.3    58.5    16.5
# 4    180.8   10.8    58.4    17.9
# ..     ...    ...     ...     ...
# 195   38.2    3.7    13.8     7.6
# 196   94.2    4.9     8.1    14.0
# 197  177.0    9.3     6.4    14.8
# 198  283.6   42.0    66.2    25.5
# 199  232.1    8.6     8.7    18.4
#
# [200 rows x 4 columns]

# %% [markdown]
# #### Análise Exploratória
# - Vamos tentar visualizar como as informações de cada item estão distribuídas
# - Vamos ver a correlação entre cada um dos itens

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(tabela.corr(), annot=True, cmap="Wistia")
#annot inclui o indice de correlação dentro do quadradinho
#wistia é a escala de cor escolhida

plt.show()

# outra forma de ver a mesma análise
# sns.pairplot(tabela)
# plt.show()

# %% [markdown]
# #### Com isso, podemos partir para a preparação dos dados para treinarmos o Modelo de Machine Learning
#
# - Separando em dados de treino e dados de teste

# %%
from sklearn.model_selection import train_test_split

y = tabela["Vendas"]
x = tabela.drop("Vendas", axis=1)

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.3, random_state=1)
#random_state=1 é para que uma vez definido o treino e o teste, mantenham-se os mesmo valores,que o random seja o mesmo sempre e nao modifique cada vez que rodar

# %% [markdown]
# #### Temos um problema de regressão - Vamos escolher os modelos que vamos usar:
#
# - Regressão Linear
# - RandomForest (Árvore de Decisão)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# define as inteligencias artificiais que serão usadas
modelo_regressaolinear = LinearRegression()
modelo_arvoredecisao = RandomForestRegressor()


#treina as inteligencias artificias

### Define usando os dados de treino o modelo - dentro das AI escolhidas

modelo_regressaolinear.fit(x_treino, y_treino)
modelo_arvoredecisao.fit(x_treino, y_treino)


### Define teste - predição

# Usando os dados de teste, usa o treino do modelo definido para gerar predição

previsao_regressaolinear = modelo_regressaolinear.predict(x_teste)
previsao_arvoredecisao = modelo_arvoredecisao.predict(x_teste)

# %% [markdown]
# #### Teste da AI e Avaliação do Melhor Modelo
#
# - Vamos usar o R² -> diz o % que o nosso modelo consegue explicar o que acontece - a eficacia de acerto do modelo

# %%
from sklearn import metrics

# comparar a eficiencia dos modelos
print(metrics.r2_score(y_teste, previsao_regressaolinear))
print(metrics.r2_score(y_teste, previsao_arvoredecisao))
# Out:
# 0.9071151423684273
# 0.9638160235974176

# %% [markdown]
# #### Visualização Gráfica das Previsões

# %%
tabela_auxiliar = pd.DataFrame()
#cria tabela vazia

#criar colunas
tabela_auxiliar["y_teste"] = y_teste
tabela_auxiliar["Previsoes ArvoreDecisao"] = previsao_arvoredecisao
tabela_auxiliar["Previsoes Regressao Linear"] = previsao_regressaolinear

plt.figure(figsize=(15,6))
sns.lineplot(data=tabela_auxiliar)
plt.show()

# %% [markdown]
# #### Como fazer uma nova previsao?

# %%
# Como fazer uma nova previsao usando novos dados 

# importar a nova_tabela com o pandas (a nova tabela tem que ter os dados de TV, Radio e Jornal)
nova_tabela = pd.read_csv("novos.csv")
display(nova_tabela)
# Out:
#       TV  Radio  Jornal
# 0   23.1    3.8    69.2
# 1   44.5    0.0     5.1
# 2  170.2   45.9     0.0

# %%
#previsao = modelo_randomforest.predict(nova_tabela) - apenas muda os dados de teste para solicitar a predição (predict).
#O modelo de treino (fit) se mantem o mesmo que foi definido anteriormente

previsao = modelo_arvoredecisao.predict(nova_tabela)
print(previsao)
# Out:
# [ 7.639  8.429 19.667]

# %% [markdown]
# Cada previsão é equivalente a uma linha - o resultado é quantos milhoes em vendas serão geradas baseando os investimentos em reais de cada um:
#
# ex: Linha 0 - para investimento de 23.1 mil em tv, 3.8 mil em radio e 69.2 mil em jornal, a venda prevista é de 7.639 milhoes

# %% [markdown]
# #### Qual a importância de cada variável para as vendas?

# %%
sns.barplot(x=x_treino.columns, y=modelo_arvoredecisao.feature_importances_)
plt.show()

# Caso queira comparar Radio com Jornal
# print(df[["Radio", "Jornal"]].sum())
